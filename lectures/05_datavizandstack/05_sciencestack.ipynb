# %% [markdown]
# ## numpy

# %%
# numpy for fast array operations
import numpy as np

# %%
# random number generator
np.random.rand(10)  # uniformly distributed
# Out:
# array([0.85160611, 0.12193894, 0.05737396, 0.25983273, 0.32162604,
#        0.49045684, 0.12743276, 0.10519929, 0.75700362, 0.96615767])

# %%
np.random.randn(10) # normally distributed
# Out:
# array([-1.00605964, -1.09955047,  0.69164235, -0.18586179, -0.98131356,
#        -0.71972212,  0.43367121, -0.64065612, -0.33635252, -1.42792499])

# %%
# basic math numbers and functions
np.pi
# Out:
# 3.141592653589793

# %%
np.cos(0), np.cos(np.pi)
# Out:
# (1.0, -1.0)

# %%
np.cos(np.arange(0,2*np.pi))
# Out:
# array([ 1.        ,  0.54030231, -0.41614684, -0.9899925 , -0.65364362,
#         0.28366219,  0.96017029])

# %%
t = np.random.randn(10)
t
# Out:
# array([-2.97064166,  2.47488506,  0.89006287, -1.28650355, -0.64154612,
#         0.60066188, -0.47366466,  1.48076803,  0.01041935,  1.21682609])

# %%
np.min(t)
# Out:
# -2.9706416610808617

# %%
# t is an array, which is an object in python, so we can also do
t.min()
# Out:
# -2.9706416610808617

# %%
t[t.argmax()]
# Out:
# 2.4748850636962616

# %%
t.mean()  # simple mean
# Out:
# 0.1301267294509963

# %%
t.std()  # standard deviation
# Out:
# 1.4797947211532667

# %%
# gridding 
x = np.arange(-np.pi,np.pi+.1,.1)
y = np.arange(-np.pi,np.pi+.1,.1)

# %%
x.shape, y.shape # x and y are 1D arrays
# Out:
# ((64,), (64,))

# %%
X, Y = np.meshgrid(x,y)

# %%
X.shape, Y.shape # X and Y are 1D arrays
# Out:
# ((64, 64), (64, 64))

# %%
f = np.exp(-(X**2 + Y**2))

# %%
f.shape
# Out:
# (64, 64)

# %%
plt.contourf(X,Y,f)
plt.colorbar()

# %%
# simple interpolation
x = np.array([0,.4,.7,1.1,1.8,2.3,2.6,3.])
f = np.cos(x)

# %%
xi = np.arange(0,np.pi,.1)
fi = np.interp(xi,x,f)

# %%
plt.plot(x,f,'o')
plt.plot(xi,fi)

# %% [markdown]
# ## scipy

# %%
# scipy for numerical operations
import scipy as sp  # basic scipy

# %%
# special functions
import scipy.special as special 
x = np.arange(0,100,.25)
jofx = special.j0(x) # zeroth-order Bessel function of first kind

# %%
# dealing with matlab files
import scipy.io as io

# %%
# !cp /shared/data/matfiles/co2_series.mat .
# co2 = io.loadmat('co2_series.mat')

# %%
# signal processing
import scipy.signal as signal

# %%
# 10-point hanning window
hanning_window = signal.hann(10)

# %%
# More advanced operations: numpy and scipy work together

# Let's create some fake data
t = np.arange(0,30*np.pi,.1)
f = 0.1*t + 2*np.cos(0.2*t) + 1.2*np.sin(3*t) + 1.2*np.cos(5*t)
plt.plot(t,f)

# %%
# detrending
f_detrended = signal.detrend(f)

# %%
plt.plot(t,f_detrended)

# %%
# window 
win = signal.hann(100)/win.sum()

# %%
# Simple filtering via convolution of
# signal against window
f_filtered = np.convolve(f_detrended,win,mode='same')

# %%
plt.plot(t,f_detrended,label='raw')
plt.plot(t,f_filtered,label='filtered')
plt.legend()
